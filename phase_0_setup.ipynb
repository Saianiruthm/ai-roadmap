# %% [markdown]
# # Phase 0: Environment Setup & Hello World
#
# This notebook confirms the 'ai-roadmap' setup and the Python environment. It prints the versions of all major libraries needed for Phases 1-5.

# %%
import sys
import numpy as np
import pandas as pd
import torch
import tensorflow as tf
import sklearn
import matplotlib
import seaborn

print("--- Hello from the AI Roadmap! ---")
print(f"Python Version: {sys.version.split(' ')[0]}")
print("\n--- Major Libraries ---")
print(f"NumPy:       {np.__version__}")
print(f"Pandas:      {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Matplotlib:  {matplotlib.__version__}")
print(f"Seaborn:     {seaborn.__version__}")
print(f"PyTorch:     {torch.__version__}")
print(f"TensorFlow:  {tf.__version__}")

print("\n--- NumPy Hello World (from Phase 0 Plan) ---")
my_array = np.array([1, 2, 3])
print(f"My first NumPy array: {my_array}")
